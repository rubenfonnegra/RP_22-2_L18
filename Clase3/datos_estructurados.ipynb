# %% [markdown]
# # Estructurando imágenes en Python

# %%
import os
import cv2
from PIL import Image
import matplotlib.pyplot as plt

# %%
path = "/content/drive/MyDrive/Docencia/Patrones/2022-2/L18/patrones/Clase3/sound_image/"

list_ext = [".jpg", ".png", ".jpeg", ".tif", ".tiff", ".bmp", ".gif"]
list_files = []

for file_ in os.listdir(path): 
  # print(os.path.splitext(file_))
  if os.path.splitext(file_)[1].lower() in list_ext: 
    #print(file_)
    list_files.append(path + file_)

print (list_files)
# Out:
# ['/content/drive/MyDrive/Docencia/Patrones/2022-2/L18/patrones/Clase3/sound_image/fruits.jpeg', '/content/drive/MyDrive/Docencia/Patrones/2022-2/L18/patrones/Clase3/sound_image/Baboon.png', '/content/drive/MyDrive/Docencia/Patrones/2022-2/L18/patrones/Clase3/sound_image/parrots.jpg', '/content/drive/MyDrive/Docencia/Patrones/2022-2/L18/patrones/Clase3/sound_image/koala.jpg', '/content/drive/MyDrive/Docencia/Patrones/2022-2/L18/patrones/Clase3/sound_image/zebras.jpg', '/content/drive/MyDrive/Docencia/Patrones/2022-2/L18/patrones/Clase3/sound_image/airplane.jpg', '/content/drive/MyDrive/Docencia/Patrones/2022-2/L18/patrones/Clase3/sound_image/louvre.jpg', '/content/drive/MyDrive/Docencia/Patrones/2022-2/L18/patrones/Clase3/sound_image/bears.jpg', '/content/drive/MyDrive/Docencia/Patrones/2022-2/L18/patrones/Clase3/sound_image/bird.jpg']

# %%
list_images = []

for image in list_files: 
  #print(image)
  image = cv2.imread(image)

  ##--- Preprocesamiento adicional ---##
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image, (256,256))

  list_images.append(image)

print(len(list_images))
# Out:
# 9

# %%
for image in list_images: 
  plt.imshow(image)
  plt.show()

# %% [markdown]
# # Estructurando audios en Python

# %%
import librosa 
from librosa.display import waveplot

# %%
audio, fs = librosa.load("/content/drive/MyDrive/Docencia/Patrones/2022-2/L18/patrones/Clase3/sound_image/13970_1459880753.mp3")
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
waveplot(audio, fs)
